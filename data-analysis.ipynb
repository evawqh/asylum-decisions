# %%
# importing
import pandas as pd

# %%
# read in the files
df_af = pd.read_csv("top10_country_affirmative.csv")
df_def = pd.read_csv("top10_country_defensive.csv")
df_ref = pd.read_csv("refugees.csv")

# %%
df_af = df_af.transpose()

# %%
df_af.columns = df_af.iloc[0]
df_af = df_af[1:]

# %%
df_af.rename(index={"country":"year"})
# Out:
# country      total China India Venezuela Nigeria Mexico Russia Bangladesh  \
# y_2012        8622  4227   189       108      12     52    167         30
# rate_2012(%)  71.7  78.6  59.4      53.2    54.5   26.9   70.8       66.7
# y_2013        8020  3975   186        71      14     70    177         33
# rate_2013     72.9  78.7  72.4      56.8    46.7   41.2   72.5       73.3
# y_2014        6586  3531   185        75      16     50    120         14
# rate_2014     74.9  78.6  77.7      71.4    66.7   32.1   76.4       77.8
# y_2015        5289  3168    94        25      14     19     90         16
# rate_2015     79.6  82.9  71.8      46.3    73.7   29.7   85.7       76.2
# y_2016        4345  2599    70        17      12     26     65         30
# rate_2016     81.9  85.7  73.7      60.7    92.3   29.2   83.3       78.9
# y_2017        4048  2172   116        39      13     17     45         47
# rate_2017     79.7  83.5  80.6      78.0    65.0   23.9   83.3       79.7
# ...

# %%
df_af.to_csv("affirmative.csv")

# %%
# hand calculate the grant rate of each year of the top 10 countries and totals
# and enter into csvs based on TRAC numbers and the cleaned up csvs
